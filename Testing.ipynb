# %%
from Scripts.test import *
# Out:
# 2025-01-21 15:51:30.340071: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-21 15:51:30.430466: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-21 15:51:30.516397: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1737454890.588375    9262 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1737454890.608105    9262 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-21 15:51:30.775415: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model_path = "Models/multiclass2/DenseNet121_SVC_kernel: linear.pkl"
image_path = 'Test_Dataset/Ripe/ripe5.jpg'

# %%
display_image(image_path)

# %%
pretrained_model, features_size = load_pretrained(model_path)
# Out:
# model_loaded : DenseNet121
# W0000 00:00:1737454895.010198    9262 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
categories = load_categories(model_path)
# Out:
# categories : ['Damaged', 'Old', 'Ripe', 'Unripe']

# %%
classifier = load_classifier(model_path)
# Out:
# Classifier : SVC
# hyperparameters : kernel: linear

# %%
predicted_label = predict_image(image_path, pretrained_model, classifier, categories,features_size)
print(f"The predicted label for the image is: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# The predicted label for the image is: Ripe
